# %% [markdown]
# # Python with APIs
# Exchanges via HTTP using `requests` package

# %%
import requests

# %% [markdown]
# ## Example

# %% [markdown]
# ### Agify API

# %% [markdown]
# Example route for Agify API

# %%
agify_dan = "https://api.agify.io/?name=dan"

# %% [markdown]
# Extract response

# %%
# Run a GET request
agify_answer = requests.get(agify_dan)
agify_answer_txt = agify_answer.text
agify_answer_json = agify_answer.json()

print(f"Answer status_code: {agify_answer}")

print(type(agify_answer_txt))
print(type(agify_answer_json))

print(agify_answer_txt)
print(agify_answer_json)
# Out:
# Answer status_code: <Response [200]>
# <class 'str'>
# <class 'dict'>
# {"count":67782,"name":"dan","age":66}
# {'count': 67782, 'name': 'dan', 'age': 66}

# %% [markdown]
# ## Introductory Exercises

# %%
# Exercise 1
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the agify API

# https://api.agify.io/?name=YOUR_NAME
# Example response: {"name":"YOUR_NAME","age":30,"count":12345}

# Function to get personalized message based on predicted age
def personalized_message(name, age):
    if age is None:
        return f"Sorry, we couldn't predict your age based on the name {name}."
    else:
        return f"Hello {name.capitalize()}! Based on your name, we predict that you are around {age} years old."

# Main function
def main():
    # Ask user for their first name
    first_name = input("Please enter your first name: ").strip().lower()

    # Make a GET request to the Agify API
    agify_url = f"https://api.agify.io/?name={first_name}"
    response = requests.get(agify_url)
    
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract predicted age from response
        age = data.get('age')
        
        # Get personalized message based on predicted age
        message = personalized_message(first_name, age)
        
        # Print personalized message
        print(message)
    else:
        print("Failed to retrieve data from the Agify API.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Hello Li! Based on your name, we predict that you are around 52 years old.

# %%
# Exercise 2
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the genderize API
# https://api.genderize.io/?name=YOUR_NAME

# Function to get personalized message based on predicted gender
def get_personalized_message(name, gender):
    if gender is None:
        return f"Sorry, we couldn't predict your gender based on the name {name}."
    else:
        if gender == 'male':
            return f"Hello Mr. {name.capitalize()}! Nice to meet you."
        elif gender == 'female':
            return f"Hello Mrs./Ms. {name.capitalize()}! Nice to meet you."
        else:
            return f"Hello {name.capitalize()}! Nice to meet you."

# Main function
def main():
    # Ask user for their first name
    first_name = input("Please enter your first name: ").strip().lower()

    # Make a GET request to the Genderize API
    genderize_url = f"https://api.genderize.io/?name={first_name}"
    response = requests.get(genderize_url)
    
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract predicted gender from response
        gender = data.get('gender')
        
        # Get personalized message based on predicted gender
        message = get_personalized_message(first_name, gender)
        
        # Print personalized message
        print(message)
    else:
        print("Failed to retrieve data from the Genderize API.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Hello Mr. Chenjie! Nice to meet you.

# %%
# Exercise 3
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the nationalize API
# https://api.nationalize.io/?name=YOUR_NAME

# Function to get personalized message based on predicted nationality
def get_personalized_message(name, countries):
    if not countries:
        return f"Sorry, we couldn't predict your nationality based on the name {name}."
    else:
        countries_str = ', '.join([country['country_id'] for country in countries])
        return f"Hello {name.capitalize()}! Based on your name, you might have connections to the following countries: {countries_str}."

# Main function
def main():
    # Ask user for their first name
    first_name = input("Please enter your first name: ").strip().lower()

    # Make a GET request to the Nationalize API
    nationalize_url = f"https://api.nationalize.io/?name={first_name}"
    response = requests.get(nationalize_url)
    
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract predicted nationality from response
        countries = data.get('country')
        
        # Get personalized message based on predicted nationality
        message = get_personalized_message(first_name, countries)
        
        # Print personalized message
        print(message)
    else:
        print("Failed to retrieve data from the Nationalize API.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Hello Chenjie! Based on your name, you might have connections to the following countries: CN, SQ, ID, CA, ES.

# %%
# Exercise 3.1
# Parsing the response from the nationalize API
# Get the most probable country and its percentage
# Example response: {"name":"YOUR_NAME","country":[{"country_id":"FR","probability":0.75},{"country_id":"BE","probability":0.25}]}
# Hint: use the max() function with a lambda function
# https://docs.python.org/3/library/functions.html#max
# https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions

# Function to get the most probable country and its percentage
def get_most_probable_country(countries):
    if not countries:
        return "Sorry, we couldn't predict your nationality."
    else:
        # Find the country with the maximum probability
        max_country = max(countries, key=lambda x: x['probability'])
        country_id = max_country['country_id']
        probability = max_country['probability'] * 100  # Convert probability to percentage
        return f"The most probable country for you is {country_id} with a probability of {probability:.2f}%."

# Main function
def main():
    # Ask user for their first name
    first_name = input("Please enter your first name: ").strip().lower()

    # Make a GET request to the Nationalize API
    nationalize_url = f"https://api.nationalize.io/?name={first_name}"
    response = requests.get(nationalize_url)
    
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract predicted nationality from response
        countries = data.get('country')
        
        # Get message with the most probable country and its percentage
        message = get_most_probable_country(countries)
        
        # Print personalized message
        print(message)
    else:
        print("Failed to retrieve data from the Nationalize API.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# The most probable country for you is CN with a probability of 73.64%.

# %%
# Exercise 4
# Use BoredAPI : https://www.boredapi.com/
# Documentation : https://www.boredapi.com/documentation
# 1. Write a script that generates random activities
# 2. Write a script that generates random activities
# 3. Write a script that generates random activities for 4 participants
# 4. Write a script that generates random activities for 4 participants and of type "recreational"
# 5. Write a script that generates random activities for 2 participants and that does not require equipment

# 4.1
def get_random_activity():
    url = "https://www.boredapi.com/api/activity"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        activity = data.get('activity')
        print("Random Activity:", activity)
    else:
        print("Failed to retrieve data from Bored API.")

get_random_activity()

# 4.2
# Reusing get_random_activity() from Exercise 4.1
get_random_activity()

# 4.3
def get_random_activity_participants(participants):
    url = f"https://www.boredapi.com/api/activity?participants={participants}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        activity = data.get('activity')
        print(f"Random Activity for {participants} participants:", activity)
    else:
        print("Failed to retrieve data from Bored API.")

get_random_activity_participants(4)


# 4.4
import requests

def get_random_activity_participants_type(participants, activity_type):
    url = f"https://www.boredapi.com/api/activity?type={activity_type}&participants={participants}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        activity = data.get('activity')
        print(f"Random Recreational Activity for {participants} participants:", activity)
    else:
        print("Failed to retrieve data from Bored API.")

get_random_activity_participants_type(4, "recreational")


# 4.5
import requests

def get_random_activity_participants_no_equipment(participants):
    url = f"https://www.boredapi.com/api/activity?participants={participants}&minparticipants={participants}&maxparticipants={participants}&minaccessibility=0&maxaccessibility=0&minprice=0&maxprice=0&equipment=no"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        activity = data.get('activity')
        print(f"Random Activity for {participants} participants that doesn't require equipment:", activity)
    else:
        print("Failed to retrieve data from Bored API.")

get_random_activity_participants_no_equipment(2)
# Out:
# Random Activity: Learn how to iceskate or rollerskate
# Random Activity: Repaint a room in your house
# Random Activity for 4 participants: Have a bonfire with your close friends
# Random Recreational Activity for 4 participants: Go see a Broadway production
# Random Activity for 2 participants that doesn't require equipment: Compliment someone

# %% [markdown]
# ## Intermediate exercises

# %%
# OpenDomesday
# https://opendomesday.org/api/

# Exercise 1
# Write a script that displays all the counties  
# using the OpenDomesday API.

api_url = "https://opendomesday.org/api/1.0/county"
response = requests.get(api_url)
data = response.json()
counties = [county['name'] for county in data]
print("List of counties:")
for county in counties:
    print(county)
# Out:
# List of counties:
# Kent
# Sussex
# Surrey
# Hampshire
# Berkshire
# Wiltshire
# Dorset
# Somerset
# Devon
# Cornwall
# Middlesex
# Hertfordshire
# Buckinghamshire
# Gloucestershire
# Oxfordshire
# Worcestershire
# Herefordshire
# Cambridgeshire
# Huntingdonshire
# Bedfordshire
# Northamptonshire
# Leicestershire
# Warwickshire
# Staffordshire
# Shropshire
# Cheshire
# Derbyshire
# Nottinghamshire
# Rutland
# Yorkshire
# Lincolnshire
# Claims: YB
# Claims: YC
# Claims: LC
# Claims: HC
# Claims: YS
# Essex
# Norfolk
# Suffolk
# Lancashire

# %%
# Exercise 2
# Write a script that displays the information
# of the county "Derbyshire".

url = "http://opendomesday.org/api/1.0/county"
response = requests.get(url)
counties = response.json()
derbyshire_info = None
for county in counties:
    if county['name'] == "Derbyshire":
        derbyshire = county
        print(county)
        break
# Out:
# {'id': 'dby', 'name': 'Derbyshire', 'name_slug': 'derbyshire', 'places_in_county': [{'id': 1036}, {'id': 2558}, {'id': 3016}, {'id': 4791}, {'id': 6093}, {'id': 8701}, {'id': 8951}, {'id': 9101}, {'id': 11441}, {'id': 10771}, {'id': 16116}, {'id': 20861}, {'id': 22251}, {'id': 22571}, {'id': 22611}, {'id': 24741}, {'id': 25536}, {'id': 19061}, {'id': 30246}, {'id': 31896}, {'id': 32521}, {'id': 32981}, {'id': 33916}, {'id': 41346}, {'id': 41788}, {'id': 41801}, {'id': 45821}, {'id': 47401}, {'id': 47411}, {'id': 52361}, {'id': 52596}, {'id': 53901}, {'id': 54446}, {'id': 54646}, {'id': 55736}, {'id': 56786}, {'id': 57061}, {'id': 60236}, {'id': 60351}, {'id': 60816}, {'id': 63606}, {'id': 65368}, {'id': 73221}, {'id': 73731}, {'id': 73741}, {'id': 91}, {'id': 2623}, {'id': 3011}, {'id': 3941}, {'id': 4046}, {'id': 5016}, {'id': 5676}, {'id': 7111}, {'id': 7116}, {'id': 7451}, {'id': 9056}, {'id': 10981}, {'id': 11656}, {'id': 11941}, {'id': 12751}, {'id': 13401}, {'id': 14081}, {'id': 14306}, {'id': 15306}, {'id': 15451}, {'id': 17386}, {'id': 17811}, {'id': 19611}, {'id': 22436}, {'id': 22476}, {'id': 24011}, {'id': 24306}, {'id': 25081}, {'id': 27521}, {'id': 33816}, {'id': 40056}, {'id': 28311}, {'id': 29846}, {'id': 30061}, {'id': 30211}, {'id': 30536}, {'id': 30571}, {'id': 20391}, {'id': 32571}, {'id': 33016}, {'id': 36211}, {'id': 37586}, {'id': 40057}, {'id': 39661}, {'id': 39956}, {'id': 40466}, {'id': 42799}, {'id': 43751}, {'id': 44321}, {'id': 28296}, {'id': 34241}, {'id': 46861}, {'id': 26971}, {'id': 2366}, {'id': 48026}, {'id': 49236}, {'id': 50311}, {'id': 52766}, {'id': 52791}, {'id': 55006}, {'id': 55131}, {'id': 58231}, {'id': 59051}, {'id': 42936}, {'id': 61396}, {'id': 62566}, {'id': 63721}, {'id': 67724}, {'id': 69701}, {'id': 72781}, {'id': 73841}, {'id': 14941}, {'id': 20691}, {'id': 39371}, {'id': 42171}, {'id': 54526}, {'id': 46681}, {'id': 51241}, {'id': 64663}, {'id': 70526}, {'id': 1326}, {'id': 2401}, {'id': 3291}, {'id': 4001}, {'id': 8116}, {'id': 8831}, {'id': 9461}, {'id': 10196}, {'id': 12706}, {'id': 13281}, {'id': 22243}, {'id': 18184}, {'id': 18736}, {'id': 23231}, {'id': 6141}, {'id': 29236}, {'id': 29861}, {'id': 32336}, {'id': 33086}, {'id': 34446}, {'id': 35221}, {'id': 35041}, {'id': 37056}, {'id': 38231}, {'id': 40456}, {'id': 41344}, {'id': 42041}, {'id': 42046}, {'id': 42797}, {'id': 45553}, {'id': 46851}, {'id': 48266}, {'id': 49221}, {'id': 55881}, {'id': 56826}, {'id': 56941}, {'id': 61526}, {'id': 62731}, {'id': 63966}, {'id': 66911}, {'id': 68251}, {'id': 68481}, {'id': 68546}, {'id': 71226}, {'id': 71466}, {'id': 1136}, {'id': 1456}, {'id': 1596}, {'id': 2106}, {'id': 3163}, {'id': 4646}, {'id': 5396}, {'id': 8456}, {'id': 11731}, {'id': 14476}, {'id': 18001}, {'id': 19416}, {'id': 22741}, {'id': 23256}, {'id': 23731}, {'id': 24921}, {'id': 35046}, {'id': 35311}, {'id': 37656}, {'id': 39466}, {'id': 39566}, {'id': 40901}, {'id': 41658}, {'id': 42536}, {'id': 42741}, {'id': 44361}, {'id': 45893}, {'id': 47416}, {'id': 49901}, {'id': 50661}, {'id': 50806}, {'id': 54966}, {'id': 56216}, {'id': 58701}, {'id': 61046}, {'id': 63391}, {'id': 65696}, {'id': 69008}, {'id': 69081}, {'id': 70641}, {'id': 8956}, {'id': 9586}, {'id': 9611}, {'id': 13741}, {'id': 13806}, {'id': 16581}, {'id': 18621}, {'id': 19941}, {'id': 20101}, {'id': 21051}, {'id': 21326}, {'id': 28556}, {'id': 30666}, {'id': 31306}, {'id': 32361}, {'id': 33141}, {'id': 33376}, {'id': 34646}, {'id': 35946}, {'id': 37591}, {'id': 14686}, {'id': 22266}, {'id': 28563}, {'id': 22271}, {'id': 41006}, {'id': 41521}, {'id': 43091}, {'id': 43991}, {'id': 46746}, {'id': 48806}, {'id': 51961}, {'id': 52096}, {'id': 53806}, {'id': 53996}, {'id': 55576}, {'id': 55956}, {'id': 56606}, {'id': 56696}, {'id': 57526}, {'id': 58046}, {'id': 58196}, {'id': 66498}, {'id': 16166}, {'id': 18951}, {'id': 22546}, {'id': 58356}, {'id': 71196}, {'id': 986}, {'id': 2711}, {'id': 4311}, {'id': 4369}, {'id': 5791}, {'id': 7651}, {'id': 8016}, {'id' ...

# %%
# Exercise 3
# Now that we have the ids for all the places in Derbyshire, we can load all their details...
# And from their details, we can list all the details of their manors.
# Go fetch the data!
# P.S.: remember to save the data to avoid downloading it every time

place_details = []
places_in_country = derbyshire.get('places_in_county')
print(places_in_country)
for place in places_in_country:
    place_id = place['id']
    response = requests.get(f"http://opendomesday.org/api/1.0/place/{place_id}")
    place_detail = response.json()
    place_details.append(place_detail)
    
print(place_details[0])
# Out:
# [{'id': 1036}, {'id': 2558}, {'id': 3016}, {'id': 4791}, {'id': 6093}, {'id': 8701}, {'id': 8951}, {'id': 9101}, {'id': 11441}, {'id': 10771}, {'id': 16116}, {'id': 20861}, {'id': 22251}, {'id': 22571}, {'id': 22611}, {'id': 24741}, {'id': 25536}, {'id': 19061}, {'id': 30246}, {'id': 31896}, {'id': 32521}, {'id': 32981}, {'id': 33916}, {'id': 41346}, {'id': 41788}, {'id': 41801}, {'id': 45821}, {'id': 47401}, {'id': 47411}, {'id': 52361}, {'id': 52596}, {'id': 53901}, {'id': 54446}, {'id': 54646}, {'id': 55736}, {'id': 56786}, {'id': 57061}, {'id': 60236}, {'id': 60351}, {'id': 60816}, {'id': 63606}, {'id': 65368}, {'id': 73221}, {'id': 73731}, {'id': 73741}, {'id': 91}, {'id': 2623}, {'id': 3011}, {'id': 3941}, {'id': 4046}, {'id': 5016}, {'id': 5676}, {'id': 7111}, {'id': 7116}, {'id': 7451}, {'id': 9056}, {'id': 10981}, {'id': 11656}, {'id': 11941}, {'id': 12751}, {'id': 13401}, {'id': 14081}, {'id': 14306}, {'id': 15306}, {'id': 15451}, {'id': 17386}, {'id': 17811}, {'id': 19611}, {'id': 22436}, {'id': 22476}, {'id': 24011}, {'id': 24306}, {'id': 25081}, {'id': 27521}, {'id': 33816}, {'id': 40056}, {'id': 28311}, {'id': 29846}, {'id': 30061}, {'id': 30211}, {'id': 30536}, {'id': 30571}, {'id': 20391}, {'id': 32571}, {'id': 33016}, {'id': 36211}, {'id': 37586}, {'id': 40057}, {'id': 39661}, {'id': 39956}, {'id': 40466}, {'id': 42799}, {'id': 43751}, {'id': 44321}, {'id': 28296}, {'id': 34241}, {'id': 46861}, {'id': 26971}, {'id': 2366}, {'id': 48026}, {'id': 49236}, {'id': 50311}, {'id': 52766}, {'id': 52791}, {'id': 55006}, {'id': 55131}, {'id': 58231}, {'id': 59051}, {'id': 42936}, {'id': 61396}, {'id': 62566}, {'id': 63721}, {'id': 67724}, {'id': 69701}, {'id': 72781}, {'id': 73841}, {'id': 14941}, {'id': 20691}, {'id': 39371}, {'id': 42171}, {'id': 54526}, {'id': 46681}, {'id': 51241}, {'id': 64663}, {'id': 70526}, {'id': 1326}, {'id': 2401}, {'id': 3291}, {'id': 4001}, {'id': 8116}, {'id': 8831}, {'id': 9461}, {'id': 10196}, {'id': 12706}, {'id': 13281}, {'id': 22243}, {'id': 18184}, {'id': 18736}, {'id': 23231}, {'id': 6141}, {'id': 29236}, {'id': 29861}, {'id': 32336}, {'id': 33086}, {'id': 34446}, {'id': 35221}, {'id': 35041}, {'id': 37056}, {'id': 38231}, {'id': 40456}, {'id': 41344}, {'id': 42041}, {'id': 42046}, {'id': 42797}, {'id': 45553}, {'id': 46851}, {'id': 48266}, {'id': 49221}, {'id': 55881}, {'id': 56826}, {'id': 56941}, {'id': 61526}, {'id': 62731}, {'id': 63966}, {'id': 66911}, {'id': 68251}, {'id': 68481}, {'id': 68546}, {'id': 71226}, {'id': 71466}, {'id': 1136}, {'id': 1456}, {'id': 1596}, {'id': 2106}, {'id': 3163}, {'id': 4646}, {'id': 5396}, {'id': 8456}, {'id': 11731}, {'id': 14476}, {'id': 18001}, {'id': 19416}, {'id': 22741}, {'id': 23256}, {'id': 23731}, {'id': 24921}, {'id': 35046}, {'id': 35311}, {'id': 37656}, {'id': 39466}, {'id': 39566}, {'id': 40901}, {'id': 41658}, {'id': 42536}, {'id': 42741}, {'id': 44361}, {'id': 45893}, {'id': 47416}, {'id': 49901}, {'id': 50661}, {'id': 50806}, {'id': 54966}, {'id': 56216}, {'id': 58701}, {'id': 61046}, {'id': 63391}, {'id': 65696}, {'id': 69008}, {'id': 69081}, {'id': 70641}, {'id': 8956}, {'id': 9586}, {'id': 9611}, {'id': 13741}, {'id': 13806}, {'id': 16581}, {'id': 18621}, {'id': 19941}, {'id': 20101}, {'id': 21051}, {'id': 21326}, {'id': 28556}, {'id': 30666}, {'id': 31306}, {'id': 32361}, {'id': 33141}, {'id': 33376}, {'id': 34646}, {'id': 35946}, {'id': 37591}, {'id': 14686}, {'id': 22266}, {'id': 28563}, {'id': 22271}, {'id': 41006}, {'id': 41521}, {'id': 43091}, {'id': 43991}, {'id': 46746}, {'id': 48806}, {'id': 51961}, {'id': 52096}, {'id': 53806}, {'id': 53996}, {'id': 55576}, {'id': 55956}, {'id': 56606}, {'id': 56696}, {'id': 57526}, {'id': 58046}, {'id': 58196}, {'id': 66498}, {'id': 16166}, {'id': 18951}, {'id': 22546}, {'id': 58356}, {'id': 71196}, {'id': 986}, {'id': 2711}, {'id': 4311}, {'id': 4369}, {'id': 5791}, {'id': 7651}, {'id': 8016}, {'id': 8721}, {'id': 9218}, {'id': 10026}, {'id': 12721}, {'id': 14691}, {'id': 16356},  ...
# {'id': 1036, 'vill': 'Alkmonton', 'vill_slug': 'alkmonton', 'phillimore': '6,35', 'location': 'SRID=4326;POINT (-1.726146307392585 52.94357672901474)', 'grid': 'SK1838', 'status': None, 'xrefs': None, 'county': [{'id': 'dby'}], 'area': [], 'hundred': [{'id': 'appletree'}], 'manors': [{'id': 13038}]}

# %%
import requests

# Assuming place_details is already defined and filled with data as per previous operations
manor_ids = set()
for place_detail in place_details:
    for manor in place_detail.get('manors', []):
        manor_ids.add(manor['id'])

# Prepare the URLs for fetching manor details
manor_urls = [f"http://opendomesday.org/api/1.0/manor/{manor_id}" for manor_id in manor_ids]

# Function to fetch and process manor details
def fetch_manor_details(urls):
    manor_details = []
    for url in urls:
        print("Requesting URL:", url)
        response = requests.get(url)
        print("Status Code:", response.status_code)
        if response.status_code == 200:
            try:
                manor_detail = response.json()
                manor_details.append(manor_detail)
            except json.JSONDecodeError as e:
                print(f"Failed to decode JSON for URL {url}: {e}")
        else:
            print(f"Failed to fetch details for URL: {url}")
    return manor_details

# Fetching manor details using the function
manor_details = fetch_manor_details(manor_urls)

# Proceed with manor_details for further processing
# Out:
# Requesting URL: http://opendomesday.org/api/1.0/manor/10822
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/10823
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/10831
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/10837
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12969
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12944
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12945
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12946
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12947
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12948
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12949
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12950
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12951
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12952
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12953
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12954
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12955
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12956
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12957
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12958
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12959
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12960
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12961
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12962
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12963
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12964
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12965
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12966
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12967
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12968
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/11549
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12970
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12971
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12972
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12973
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12974
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12975
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12976
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12977
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12978
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12979
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12980
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12981
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12983
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12984
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12985
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12987
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12988
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12989
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12990
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12991
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12992
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12993
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12995
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12996
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12998
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/12999
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13000
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13001
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/10954
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13002
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13004
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13005
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13006
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13007
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13008
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13009
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13010
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13011
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13012
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13013
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13014
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13015
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13016
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13017
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13018
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13019
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13020
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13021
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13022
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13023
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13070
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13025
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13026
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13027
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13028
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13029
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13030
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13031
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13032
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13033
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13034
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13035
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13036
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13037
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13038
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13039
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13040
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13041
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13042
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13043
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13044
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13045
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13046
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13047
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13048
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13049
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13050
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13051
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13052
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13053
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13054
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13055
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13056
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13057
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13058
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13059
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13060
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13061
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13062
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13063
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13064
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13065
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13066
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13067
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/11013
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13069
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13068
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13071
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13072
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13073
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13074
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13075
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13076
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13077
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13078
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13079
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13080
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13081
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13082
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13083
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13084
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13085
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13086
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13087
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13088
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13089
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13090
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13091
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13092
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13093
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13094
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13095
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13096
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13097
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13097
# Requesting URL: http://opendomesday.org/api/1.0/manor/13098
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13099
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13100
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13101
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13102
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13103
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13104
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/11561
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13106
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13107
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13108
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13109
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13110
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13111
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13112
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13113
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13114
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13115
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13116
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13117
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13118
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13120
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13121
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13122
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13123
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13124
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13125
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13127
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13128
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13129
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13130
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13131
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13132
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13134
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13135
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13136
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13137
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13138
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13139
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13140
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13141
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13142
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13143
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13144
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13145
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13145
# Requesting URL: http://opendomesday.org/api/1.0/manor/13146
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13146
# Requesting URL: http://opendomesday.org/api/1.0/manor/13147
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13147
# Requesting URL: http://opendomesday.org/api/1.0/manor/13148
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13148
# Requesting URL: http://opendomesday.org/api/1.0/manor/13149
# Status Code: 502
# Failed to fetch details for URL: http://opendomesday.org/api/1.0/manor/13149
# Requesting URL: http://opendomesday.org/api/1.0/manor/13150
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13151
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13152
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13153
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13154
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13155
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13156
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13157
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13158
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13159
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13160
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13162
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13163
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13164
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13165
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13166
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13168
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13169
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13170
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13171
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13172
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13174
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13175
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13177
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13178
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13179
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13180
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13181
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13182
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13183
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13184
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13185
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13186
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13187
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13189
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13191
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13192
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13193
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13194
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13195
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13196
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13197
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13198
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13200
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13201
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13202
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13203
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13204
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13205
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13206
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13207
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13208
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13209
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13210
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13211
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13212
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13213
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13214
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13215
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13216
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13217
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13218
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13219
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13220
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13221
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13222
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13223
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13224
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13225
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13226
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13227
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13228
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13229
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13230
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13231
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13233
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13234
# Status Code: 200
# Requesting URL: http://opendomesday.org/api/1.0/manor/13024
# Status Code: 200

# %%
print(manor_details)
# Exercise 4
# Now that we have a quantity of raw data, we will extract the interesting parts.  
# In our case, we want to count the money paid by each manor and compare it to the number of ploughs it has.  
# - Can you find the corresponding json fields?  
# - Then, you can list these numbers for each manor in Derbyshire.  
# - And format this in an appropriate comma-separated values (CSV) file.

import csv

# Define the CSV file name
csv_file_name = 'manor_details.csv'

# CSV headers
headers = ['Manor ID', 'County ID', 'Geld (Money Paid)', 'Value in 1086']

# Writing to CSV
with open(csv_file_name, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the headers
    writer.writerow(headers)
    
    # Iterate through each manor and write its details
    for manor in manor_details:
        manor_id = manor.get('id', 'Unknown')
        county_id = manor.get('county', {}).get('id', 'Unknown')
        geld = manor.get('geld', 0)  # Assuming geld as "money paid"
        value86 = manor.get('value86', 0)  # Assuming value in 1086 as an interesting value to compare
        
        writer.writerow([manor_id, county_id, geld, value86])

print(f"Data has been written to {csv_file_name}.")


import csv
import json
import os

def extract_manor_data(base_dir='derbyshire_places'):
    """
    Extracts and saves manor data (money paid and number of ploughs) to a CSV file.
    """
    output_file = 'derbyshire_manors.csv'
    headers = ['Place ID', 'Manor Name', 'Money Paid', 'Number of Ploughs']
    
    with open(output_file, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(headers)
        
        # Iterate over each JSON file in the directory
        for filename in os.listdir(base_dir):
            if filename.endswith('.json'):
                place_id = filename.replace('.json', '')
                file_path = os.path.join(base_dir, filename)
                
                with open(file_path, 'r') as file:
                    data = json.load(file)
                    # Assuming manors are stored in a 'manors' list within the place data
                    # Adjust the path to access manor details based on your actual JSON structure
                    for manor in data.get('manors', []):
                        manor_name = manor.get('name', 'Unknown')
                        money_paid = manor.get('money_paid', 0)  # Adjust field name as necessary
                        ploughs = manor.get('ploughs', 0)  # Adjust field name as necessary
                        
                        writer.writerow([place_id, manor_name, money_paid, ploughs])

    print(f"Manor data extracted to {output_file}.")

extract_manor_data()
# Out:
# [{'id': 10822, 'county': {'id': 'lec'}, 'place': [{'id': 54526}], 'phillimore': '14,19', 'headofmanor': None, 'duplicates': None, 'subholdings': None, 'notes': None, 'waste': 'none', 'waste66': 'N', 'wasteqr': 'N', 'waste86': 'N', 'geld': 7.0, 'gcode': 'geld', 'villtax': None, 'taxedon': None, 'value86': 1.0, 'value66': None, 'valueqr': 1.0, 'value_string': '1.00', 'render': None, 'lordsland': None, 'newland': None, 'ploughlands': 5.0, 'pcode': 'tre', 'lordsploughs': 0.0, 'mensploughs': 2.0, 'totalploughs': 2.0, 'lordsploughspossible': None, 'mensploughspossible': None, 'villagers': 2.0, 'smallholders': 0.0, 'slaves': 0.0, 'femaleslaves': 0.0, 'freemen': 4.0, 'free2men': 0.0, 'priests': 0.0, 'cottagers': 0.0, 'otherpop': 0.0, 'miscpop': 0.0, 'miscpopcategories': None, 'burgesses': 0.0, 'mills': None, 'millvalue': None, 'meadow': None, 'meadowunits': None, 'pasture': None, 'pastureunits': None, 'woodland': '6 * 4', 'woodlandunits': 'furlongs', 'fisheries': None, 'salthouses': None, 'payments': None, 'paymentsunits': None, 'churches': None, 'churchland': None, 'cobs_1086': None, 'cobs_1066': None, 'cattle_1086': None, 'cattle_1066': None, 'cows_1086': None, 'cows_1066': None, 'pigs_1086': None, 'pigs_1066': None, 'sheep_1086': None, 'sheep_1066': None, 'goats_1086': None, 'goats_1066': None, 'beehives_1086': None, 'beehives_1066': None, 'wild_mares_1086': None, 'wild_mares_1066': None, 'other_1086': None, 'other_code_1086': None, 'other_1066': None, 'other_codes_1066': None, 'lord66': [], 'overlord66': [], 'lord86': [457750], 'teninchief': [275100], 'image_for_manor': [{'manor': {'id': 10822}, 'x1': 202, 'x2': 848, 'y1': 253, 'y2': 367, 'image': 'lec/08.png'}]}, {'id': 10823, 'county': {'id': 'lec'}, 'place': [{'id': 54526}], 'phillimore': '14,20', 'headofmanor': None, 'duplicates': None, 'subholdings': None, 'notes': None, 'waste': 'none', 'waste66': 'N', 'wasteqr': 'N', 'waste86': 'N', 'geld': 6.0, 'gcode': 'geld', 'villtax': None, 'taxedon': None, 'value86': 3.0, 'value66': None, 'valueqr': 1.0, 'value_string': '1.00', 'render': None, 'lordsland': None, 'newland': None, 'ploughlands': 3.0, 'pcode': 'tre', 'lordsploughs': 3.0, 'mensploughs': 3.0, 'totalploughs': 6.0, 'lordsploughspossible': None, 'mensploughspossible': None, 'villagers': 21.0, 'smallholders': 12.0, 'slaves': 0.0, 'femaleslaves': 0.0, 'freemen': 0.0, 'free2men': 0.0, 'priests': 0.0, 'cottagers': 0.0, 'otherpop': 0.0, 'miscpop': 0.0, 'miscpopcategories': None, 'burgesses': 0.0, 'mills': 1.0, 'millvalue': 0.25, 'meadow': '12', 'meadowunits': 'acres', 'pasture': None, 'pastureunits': None, 'woodland': None, 'woodlandunits': None, 'fisheries': None, 'salthouses': None, 'payments': None, 'paymentsunits': None, 'churches': None, 'churchland': None, 'cobs_1086': None, 'cobs_1066': None, 'cattle_1086': None, 'cattle_1066': None, 'cows_1086': None, 'cows_1066': None, 'pigs_1086': None, 'pigs_1066': None, 'sheep_1086': None, 'sheep_1066': None, 'goats_1086': None, 'goats_1066': None, 'beehives_1086': None, 'beehives_1066': None, 'wild_mares_1086': None, 'wild_mares_1066': None, 'other_1086': None, 'other_code_1086': None, 'other_1066': None, 'other_codes_1066': None, 'lord66': [], 'overlord66': [], 'lord86': [457750], 'teninchief': [275100], 'image_for_manor': [{'manor': {'id': 10823}, 'x1': 202, 'x2': 839, 'y1': 335, 'y2': 492, 'image': 'lec/08.png'}]}, {'id': 10831, 'county': {'id': 'lec'}, 'place': [{'id': 16741}, {'id': 20691}, {'id': 60036}], 'phillimore': '14,28', 'headofmanor': None, 'duplicates': None, 'subholdings': None, 'notes': 'Waste: no recorded resources but valued at 2s.', 'waste': 'waste except', 'waste66': 'X', 'wasteqr': 'X', 'waste86': 'Y', 'geld': 3.0, 'gcode': 'geld', 'villtax': None, 'taxedon': None, 'value86': 0.1, 'value66': None, 'valueqr': None, 'value_string': None, 'render': None, 'lordsland': None, 'newland': None, 'ploughlands': None, 'pcode': 'no ploughlands', 'lordsploughs': 0.0, 'mensploughs': 0.0, 'totalploughs': 0.0, 'lordsploughspossi ...
# Data has been written to manor_details.csv.
# Manor data extracted to derbyshire_manors.csv.

# %%
# Exercise 5
# What is the richest manor in Derbyshire?

manor_moneyPaid_NumberOfPloughs =  []

for manor_detail in manor_details:
    details = {
        "id": manor_detail.get('id'),
        "moneyPaid": manor_detail.get('geld'),
        "number of ploughs": manor_detail.get('ploughlands')
    }
    manor_moneyPaid_NumberOfPloughs.append(details)

print(manor_moneyPaid_NumberOfPloughs)

# %%
# Exercise 6
# Give the total value paid by Derbyshire.

#######################################################
################## YOUR ANSWER HERE ##################
#######################################################

# %%
# Exercise 7
# Create a Python class.  
# It must include all the previous functionalities.  
# Refactor your code to make it readable, efficient, and maintainable.

#######################################################
################## YOUR ANSWER HERE ##################
#######################################################

# %%
# Exercise 8 (optional)
# Add to your class a system for error handling.  
# It must manage the following errors:  
# - Connection error  
# - Parsing error  
# - Request error  
# - Response error  
# - Parameter error

#######################################################
################## YOUR ANSWER HERE ##################
#######################################################
