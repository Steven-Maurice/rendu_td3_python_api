# %% [markdown]
# # Python with APIs
# Exchanges via HTTP using `requests` package

# %%
import requests

# %% [markdown]
# ## Example

# %% [markdown]
# ### Agify API

# %% [markdown]
# Example route for Agify API

# %%
agify_dan = "https://api.agify.io/?name=marco"

# %% [markdown]
# Extract response

# %%
# Run a GET request
agify_answer = requests.get(agify_dan)
agify_answer_txt = agify_answer.text
agify_answer_json = agify_answer.json()

print(f"Answer status_code: {agify_answer}")

print(type(agify_answer_txt))
print(type(agify_answer_json))

print(agify_answer_txt)
print(agify_answer_json)
# Out:
# Answer status_code: <Response [200]>
# <class 'str'>
# <class 'dict'>
# {"count":345990,"name":"marco","age":52}
# {'count': 345990, 'name': 'marco', 'age': 52}

# %% [markdown]
# ## Introductory Exercises

# %% [markdown]
# # Exercise 1
#
# Write a script that asks the user for their first name and responds with a personalized message using the agify API

# %%
my_url = "https://api.agify.io/?name=MARCO_BOUSSEAU"
first_name = input("Enter your first name: ")

agify_url = f"https://api.agify.io/?name={first_name}"
response = requests.get(agify_url)

if response.status_code == 200:
    data = response.json()
    age = data.get('age')
    if age:
        message = f"Hello {first_name}, you are approximately {age} years old!"
    else:
        message = f"Sorry, we couldn't determine your age."
    print(message)
else:
    print("Error: Failed to retrieve data from the Agify API.")
# Out:
# Hello Marco, you are approximately 52 years old!

# %% [markdown]
# # Exercise 2
#
# Write a script that asks the user for their first name and responds with a personalized message using the genderize API :
# `https://api.genderize.io/?name=YOUR_NAME`

# %%
first_name = input("Enter your first name: ")

genderize_url = f"https://api.genderize.io/?name={first_name}"

response = requests.get(genderize_url)

if response.status_code == 200:
    data = response.json()
    gender = data.get('gender')
    if gender:
        message = f"Hello {first_name}, you are a {gender}!"
    else:
        message = f"Sorry, we couldn't determine your gender."
    print(message)
else:
    print("Error: Failed to retrieve data from the Genderize API.")
# Out:
# Hello Marco, you are a male!

# %% [markdown]
# # Exercise 3
#
# Write a script that asks the user for their first name and responds with a personalized message using the nationalize API : `https://api.nationalize.io/?name=YOUR_NAME`

# %%
first_name = input("Enter your first name: ")

nationalize_url = f"https://api.nationalize.io/?name={first_name}"
response = requests.get(nationalize_url)

if response.status_code == 200:
    data = response.json()
    countries = data.get('country')
    if countries:
        country_names = [country.get('country_id') for country in countries]
        message = f"Hello {first_name}, you are likely from {', '.join(country_names)}!"
    else:
        message = f"Sorry, we couldn't determine your nationality."
    print(message)
else:
    print("Error: Failed to retrieve data from the nationalize API.")
# Out:
# Hello Marco, you are likely from IT, ES, CH, PH, TZ!

# %% [markdown]
# # Exercise 3.1
#
# Parsing the response from the nationalize API Get the most probable country and its percentage Example response:
#
# ```{json}
# {
#     "name":"YOUR_NAME",
#     "country":
#     [
#         {
#             "country_id":"FR",
#             "probability":0.75
#         },
#         {
#             "country_id":"BE",
#             "probability":0.25
#         }
#     ]
# }
# ```
#
# Hint: use the max() function with a lambda function
#
# `https://docs.python.org/3/library/functions.html#max`
#
# `https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions`

# %%
data = response.json()

countries = data.get('country')

most_probable_country = max(countries, key=lambda x: x['probability'])

country_id = most_probable_country['country_id']
probability = most_probable_country['probability']

print(f"The most probable country is {country_id} with a probability of {probability}.")
# Out:
# The most probable country is IT with a probability of 0.12600175020445165.

# %% [markdown]
# # Exercise 4
#
# Use BoredAPI : `https://www.boredapi.com/`
#
# Documentation : `https://www.boredapi.com/documentation`
#
# 1. Write a script that generates random activities
# 2. Write a script that generates random activities
# 3. Write a script that generates random activities for 4 participants
# 4. Write a script that generates random activities for 4 participants and of type "recreational"
# 5. Write a script that generates random activities for 2 participants and that does not require equipment

# %%
response = requests.get("https://www.boredapi.com/api/activity")

if response.status_code == 200:
    data = response.json()
    activity = data.get('activity')
    print(f"Random Activity: {activity}")
else:
    print("Error: Failed to retrieve data from the BoredAPI.")


response = requests.get("https://www.boredapi.com/api/activity?participants=4")

if response.status_code == 200:
    data = response.json()
    activity = data.get('activity')
    print(f"Random Activity for 4 participants: {activity}")


response = requests.get("https://www.boredapi.com/api/activity", params={"participants": 4, "type": "recreational"})

if response.status_code == 200:
    data = response.json()
    activity = data.get('activity')
    print(f"Random Recreational Activity for 4 participants: {activity}")
else:
    print("Error: Failed to retrieve data from the BoredAPI.")


response = requests.get("https://www.boredapi.com/api/activity", params={"type": "recreational", "price": 0})

if response.status_code == 200:
    data = response.json()
    activity = data.get('activity')
    print(f"Random Recreational Activity without equipment for 2 participants: {activity}")
else:
    print("Error: Failed to retrieve data from the BoredAPI.")
# Out:
# Random Activity: Paint the first thing you see
# Random Activity for 4 participants: Have a bonfire with your close friends
# Random Recreational Activity for 4 participants: Go see a Broadway production
# Random Recreational Activity without equipment for 2 participants: Draw something interesting

# %% [markdown]
# ## Intermediate exercises

# %% [markdown]
# ## OpenDomesday
#
# `https://opendomesday.org/api/`
#
# # Exercise 1
#
# Write a script that displays all the counties using the OpenDomesday API.

# %%
import json
def save_to_json(data: dict, filename: str) -> None:
    with open("./data/" + filename, "w") as file:
        json.dump(data, file, indent=4)
    print(f"Data saved to {filename}")

def load_from_json(filename: str) -> dict:
    with open("./data/" + filename, "r") as file:
        data = dict(json.load(file))
    return data
    

response = requests.get("https://opendomesday.org/api/1.0/county")

if response.status_code == 200:
    data = response.json()
    #for county in data:
    #    print(str(county['name']) + " - " + str(county['id']))
    save_to_json(data, "counties.json")
# Out:
# Data saved to counties.json

# %% [markdown]
# # Exercise 2
#
# Write a script that displays the information of the county "Derbyshire".

# %%
# Geting the Derbyshire county id
response = requests.get("https://opendomesday.org/api/1.0/county")

if response.status_code == 200:
    data = response.json()
    for county in data:
        if county['name'] == 'Derbyshire':
            county_id = county['id']

response = requests.get("https://opendomesday.org/api/1.0/county/" + str(county_id))

if response.status_code == 200:
    data = response.json()
    for key in data.keys():
        if key != 'places_in_county':
            print(f"{key}: {data[key]}")
        else:
            for place in data[key]:
                place_response = requests.get("http://opendomesday.org/api/1.0/place/" + str(place['id']))
                place_data = place_response.json()
                save_to_json(place_data, f"place_{place_data['vill']}.json")
                # print(f"Place: {place_data['vill']}")
    save_to_json(data, "derbyshire.json")
# Out:
# id: dby
# name: Derbyshire
# name_slug: derbyshire
# Data saved to place_Alkmonton.json
# Place: Alkmonton
# Data saved to place_Ashe.json
# Place: Ashe
# Data saved to place_Aston.json
# Place: Aston
# Data saved to place_Barton [Blount].json
# Place: Barton [Blount]
# Data saved to place_Bentley.json
# Place: Bentley
# Data saved to place_Boylestone.json
# Place: Boylestone
# Data saved to place_Bradley.json
# Place: Bradley
# Data saved to place_Brailsford.json
# Place: Brailsford
# Data saved to place_Bupton.json
# Place: Bupton
# Data saved to place_[Church] Broughton.json
# Place: [Church] Broughton
# Data saved to place_Clifton.json
# Place: Clifton
# Data saved to place_Doveridge.json
# Place: Doveridge
# Data saved to place_Eaton [Dovedale].json
# Place: Eaton [Dovedale]
# Data saved to place_Edlaston.json
# Place: Edlaston
# Data saved to place_Ednaston.json
# Place: Ednaston
# Data saved to place_Fenton.json
# Place: Fenton
# Data saved to place_Foston.json
# Place: Foston
# Data saved to place_[Great and Little] Cubley.json
# Place: [Great and Little] Cubley
# Data saved to place_Hatton.json
# Place: Hatton
# Data saved to place_Hilton.json
# Place: Hilton
# Data saved to place_Hollington.json
# Place: Hollington
# Data saved to place_Hoon.json
# Place: Hoon
# Data saved to place_Hulland.json
# Place: Hulland
# Data saved to place_Mapperley.json
# Place: Mapperley
# Data saved to place_Marston [Montgomery]?.json
# Place: Marston [Montgomery]?
# Data saved to place_Marston [-on-Dove].json
# Place: Marston [-on-Dove]
# Data saved to place_Norbury.json
# Place: Norbury
# Data saved to place_Osleston.json
# Place: Osleston
# Data saved to place_Osmaston.json
# Place: Osmaston
# Data saved to place_Rodsley.json
# Place: Rodsley
# Data saved to place_Roston.json
# Place: Roston
# Data saved to place_Sapperton.json
# Place: Sapperton
# Data saved to place_Scropton.json
# Place: Scropton
# Data saved to place_Sedsall.json
# Place: Sedsall
# Data saved to place_Shirley.json
# Place: Shirley
# Data saved to place_Snelston.json
# Place: Snelston
# Data saved to place_Somersal.json
# Place: Somersal
# Data saved to place_Sturston [Hall] and [Nether] Sturston.json
# Place: Sturston [Hall] and [Nether] Sturston
# Data saved to place_Sudbury.json
# Place: Sudbury
# Data saved to place_Sutton [-on-the-Hill].json
# Place: Sutton [-on-the-Hill]
# Data saved to place_Thurvaston.json
# Place: Thurvaston
# Data saved to place_Trusley?.json
# Place: Trusley?
# Data saved to place_Wyaston.json
# Place: Wyaston
# Data saved to place_Yeaveley.json
# Place: Yeaveley
# Data saved to place_Yeldersley.json
# Place: Yeldersley
# Data saved to place_Abney.json
# Place: Abney
# Data saved to place_Ashford [-in-the-Water].json
# Place: Ashford [-in-the-Water]
# Data saved to place_Aston.json
# Place: Aston
# Data saved to place_Bakewell.json
# Place: Bakewell
# Data saved to place_Bamford.json
# Place: Bamford
# Data saved to place_Baslow.json
# Place: Baslow
# Data saved to place_Beeley.json
# Place: Beeley
# Data saved to place_Birchills.json
# Place: Birchills
# Data saved to place_Birchover.json
# Place: Birchover
# Data saved to place_Blackwell.json
# Place: Blackwell
# Data saved to place_Bradwell.json
# Place: Bradwell
# Data saved to place_Bubnell.json
# Place: Bubnell
# Data saved to place_Burley.json
# Place: Burley
# Data saved to place_Burton.json
# Place: Burton
# Data saved to place_Calver.json
# Place: Calver
# Data saved to place_Castleton.json
# Place: Castleton
# Data saved to place_Charlesworth.json
# Place: Charlesworth
# Data saved to place_Chatsworth.json
# Place: Chatsworth
# Data saved to place_Chisworth and [Higher] Chisworth.json
# Place: Chisworth and [Higher] Chisworth
# Data saved to place_Chunal.json
# Place: Chunal
# Data saved to place_Conksbury.json
# Place: Conksbury
# Data saved to place_Cotes.json
# Place: Cotes
# Data saved to place_Darley.json
# Place: Darley
# Data saved to place_Edale.json
# Place: Edale
# Data saved to place_Edensor.json
# Place: Edensor
# Data saved to place_Eyam.json
# Place: Eyam
# Data saved to place_Farley.json
# Place: Farley
# Data saved to place_Flagg.json
# Place: Flagg
# Data saved to place_Gratton.json
# Place: Gratton
# Data saved to place_[Great and Little] Hucklow.json
# Place: [Great and Little] Hucklow
# Data saved to place_[Great] Longstone.json
# Place: [Great] Longstone
# Data saved to place_Hadfield.json
# Place: Hadfield
# Data saved to place_Harthill.json
# Place: Harthill
# Data saved to place_Hassop.json
# Place: Hassop
# Data saved to place_Hathersage.json
# Place: Hathersage
# Data saved to place_Hayfield?.json
# Place: Hayfield?
# Data saved to place_Hazelbadge.json
# Place: Hazelbadge
# Data saved to place_[Higher and Lower] Dinting.json
# Place: [Higher and Lower] Dinting
# Data saved to place_Holme.json
# Place: Holme
# Data saved to place_Hope.json
# Place: Hope
# Data saved to place_Kinder.json
# Place: Kinder
# Data saved to place_Langley.json
# Place: Langley
# Data saved to place_[Little?] Longstone.json
# Place: [Little?] Longstone
# Data saved to place_Litton.json
# Place: Litton
# Data saved to place_Longdendale.json
# Place: Longdendale
# Data saved to place_Ludworth.json
# Place: Ludworth
# Data saved to place_Middleton.json
# Place: Middleton
# Data saved to place_Monyash.json
# Place: Monyash
# Data saved to place_Muchedeswelle.json
# Place: Muchedeswelle
# Data saved to place_[Nether and Over] Haddon.json
# Place: [Nether and Over] Haddon
# Data saved to place_[Nether and Upper] Hurst.json
# Place: [Nether and Upper] Hurst
# Data saved to place_Offerton.json
# Place: Offerton
# Data saved to place_Old Glossop.json
# Place: Old Glossop
# Data saved to place_One Ash.json
# Place: One Ash
# Data saved to place_Padfield and [Little] Padfield.json
# Place: Padfield and [Little] Padfield
# Data saved to place_Pilsley.json
# Place: Pilsley
# Data saved to place_Priestcliffe.json
# Place: Priestcliffe
# Data saved to place_Rowland.json
# Place: Rowland
# Data saved to place_Rowsley.json
# Place: Rowsley
# Data saved to place_Shatton.json
# Place: Shatton
# Data saved to place_Sheldon.json
# Place: Sheldon
# Data saved to place_Stanton [-in-Peak].json
# Place: Stanton [-in-Peak]
# Data saved to place_Stoke.json
# Place: Stoke
# Data saved to place_[Stoney] Middleton.json
# Place: [Stoney] Middleton
# Data saved to place_Taddington.json
# Place: Taddington
# Data saved to place_Thornsett.json
# Place: Thornsett
# Data saved to place_Tideswell.json
# Place: Tideswell
# Data saved to place_Watrefeld.json
# Place: Watrefeld
# Data saved to place_Whitfield.json
# Place: Whitfield
# Data saved to place_Wormhill.json
# Place: Wormhill
# Data saved to place_Youlgrave.json
# Place: Youlgrave
# Data saved to place_Chilcote.json
# Place: Chilcote
# Data saved to place_Donisthorpe.json
# Place: Donisthorpe
# Data saved to place_Linton.json
# Place: Linton
# Data saved to place_Measham.json
# Place: Measham
# Data saved to place_[Nether or Over] Seal.json
# Place: [Nether or Over] Seal
# Data saved to place_Oakthorpe.json
# Place: Oakthorpe
# Data saved to place_Ravenstone.json
# Place: Ravenstone
# Data saved to place_Trangesbi.json
# Place: Trangesbi
# Data saved to place_Willesley.json
# Place: Willesley
# Data saved to place_Alsop [-en-le-Dale].json
# Place: Alsop [-en-le-Dale]
# Data saved to place_Ashbourne.json
# Place: Ashbourne
# Data saved to place_Atlow.json
# Place: Atlow
# Data saved to place_Ballidon.json
# Place: Ballidon
# Data saved to place_Bonsall.json
# Place: Bonsall
# Data saved to place_Bradbourne.json
# Place: Bradbourne
# Data saved to place_Brassington.json
# Place: Brassington
# Data saved to place_Broadlowash.json
# Place: Broadlowash
# Data saved to place_Callow.json
# Place: Callow
# Data saved to place_Carsington.json
# Place: Carsington
# Data saved to place_[Cold] Eaton.json
# Place: [Cold] Eaton
# Data saved to place_Cowley.json
# Place: Cowley
# Data saved to place_Cromford.json
# Place: Cromford
# Data saved to place_Elton.json
# Place: Elton
# Data saved to place_[Fenny] Bentley.json
# Place: [Fenny] Bentley
# Data saved to place_Hanson [Grange].json
# Place: Hanson [Grange]
# Data saved to place_Hartington.json
# Place: Hartington
# Data saved to place_Hognaston.json
# Place: Hognaston
# Data saved to place_Hopton.json
# Place: Hopton
# Data saved to place_Ible.json
# Place: Ible
# Data saved to place_Ivonbrook [Grange].json
# Place: Ivonbrook [Grange]
# Data saved to place_[Kirk] Ireton.json
# Place: [Kirk] Ireton
# Data saved to place_Kniveton.json
# Place: Kniveton
# Data saved to place_Lea.json
# Place: Lea
# Data saved to place_Ludwell.json
# Place: Ludwell
# Data saved to place_Mapleton.json
# Place: Mapleton
# Data saved to place_Matlock.json
# Place: Matlock
# Data saved to place_Matlock [Bridge]?.json
# Place: Matlock [Bridge]?
# Data saved to place_Middleton.json
# Place: Middleton
# Data saved to place_Newton [Grange].json
# Place: Newton [Grange]
# Data saved to place_Offcote.json
# Place: Offcote
# Data saved to place_Parwich.json
# Place: Parwich
# Data saved to place_Pilsbury.json
# Place: Pilsbury
# Data saved to place_Shottle.json
# Place: Shottle
# Data saved to place_Snitterton.json
# Place: Snitterton
# Data saved to place_Soham.json
# Place: Soham
# Data saved to place_Tansley.json
# Place: Tansley
# Data saved to place_Thorpe.json
# Place: Thorpe
# Data saved to place_Tissington.json
# Place: Tissington
# Data saved to place_Wallstone.json
# Place: Wallstone
# Data saved to place_Welledene.json
# Place: Welledene
# Data saved to place_Wensley.json
# Place: Wensley
# Data saved to place_Werredune.json
# Place: Werredune
# Data saved to place_Winster.json
# Place: Winster
# Data saved to place_Wirksworth.json
# Place: Wirksworth
# Data saved to place_Allestree.json
# Place: Allestree
# Data saved to place_Alvaston.json
# Place: Alvaston
# Data saved to place_Ambaston.json
# Place: Ambaston
# Data saved to place_Arleston.json
# Place: Arleston
# Data saved to place_Aston [-on-Trent].json
# Place: Aston [-on-Trent]
# Data saved to place_Barrow [-upon-Trent].json
# Place: Barrow [-upon-Trent]
# Data saved to place_Bearwardcote.json
# Place: Bearwardcote
# Data saved to place_Boulton.json
# Place: Boulton
# Data saved to place_Burnaston.json
# Place: Burnaston
# Data saved to place_Chellaston.json
# Place: Chellaston
# Data saved to place_Cottons.json
# Place: Cottons
# Data saved to place_Dalbury.json
# Place: Dalbury
# Data saved to place_Egginton.json
# Place: Egginton
# Data saved to place_Elvaston.json
# Place: Elvaston
# Data saved to place_Etwall.json
# Place: Etwall
# Data saved to place_Findern.json
# Place: Findern
# Data saved to place_Ireton.json
# Place: Ireton
# Data saved to place_Kedleston.json
# Place: Kedleston
# Data saved to place_[Kirk] Langley.json
# Place: [Kirk] Langley
# Data saved to place_Litchurch.json
# Place: Litchurch
# Data saved to place_Littleover.json
# Place: Littleover
# Data saved to place_Mackworth.json
# Place: Mackworth
# Data saved to place_Marsh?.json
# Place: Marsh?
# Data saved to place_Mercaston.json
# Place: Mercaston
# Data saved to place_Mickleover.json
# Place: Mickleover
# Data saved to place_Mugginton.json
# Place: Mugginton
# Data saved to place_Normanton.json
# Place: Normanton
# Data saved to place_Osmaston.json
# Place: Osmaston
# Data saved to place_Potlocks.json
# Place: Potlocks
# Data saved to place_Quarndon.json
# Place: Quarndon
# Data saved to place_Radbourne.json
# Place: Radbourne
# Data saved to place_Shardlow.json
# Place: Shardlow
# Data saved to place_Sinfin.json
# Place: Sinfin
# Data saved to place_Stenson.json
# Place: Stenson
# Data saved to place_Swarkestone.json
# Place: Swarkestone
# Data saved to place_Thulston.json
# Place: Thulston
# Data saved to place_Twyford.json
# Place: Twyford
# Data saved to place_Weston [-on-Trent].json
# Place: Weston [-on-Trent]
# Data saved to place_Weston [Underwood].json
# Place: Weston [Underwood]
# Data saved to place_Willington.json
# Place: Willington
# Data saved to place_Bradley.json
# Place: Bradley
# Data saved to place_Breadsall.json
# Place: Breadsall
# Data saved to place_Breaston.json
# Place: Breaston
# Data saved to place_Cellesdene.json
# Place: Cellesdene
# Data saved to place_Chaddesden.json
# Place: Chaddesden
# Data saved to place_Codnor.json
# Place: Codnor
# Data saved to place_Crich.json
# Place: Crich
# Data saved to place_Denby.json
# Place: Denby
# Data saved to place_Derby.json
# Place: Derby
# Data saved to place_Draycott.json
# Place: Draycott
# Data saved to place_Duffield.json
# Place: Duffield
# Data saved to place_Hallam.json
# Place: Hallam
# Data saved to place_Heanor.json
# Place: Heanor
# Data saved to place_Herdebi.json
# Place: Herdebi
# Data saved to place_Holbrook.json
# Place: Holbrook
# Data saved to place_Hopwell.json
# Place: Hopwell
# Data saved to place_Horsley.json
# Place: Horsley
# Data saved to place_Ilkeston.json
# Place: Ilkeston
# Data saved to place_Kidsleypark.json
# Place: Kidsleypark
# Data saved to place_Langley.json
# Place: Langley
# Data saved to place_[Little] Chester.json
# Place: [Little] Chester
# Data saved to place_[Little] Eaton.json
# Place: [Little] Eaton
# Data saved to place_[Little?] Hallam.json
# Place: [Little?] Hallam
# Data saved to place_[Long] Eaton.json
# Place: [Long] Eaton
# Data saved to place_Makeney.json
# Place: Makeney
# Data saved to place_Markeaton.json
# Place: Markeaton
# Data saved to place_Milford.json
# Place: Milford
# Data saved to place_Morley.json
# Place: Morley
# Data saved to place_Ockbrook.json
# Place: Ockbrook
# Data saved to place_Pentrich.json
# Place: Pentrich
# Data saved to place_Ripley.json
# Place: Ripley
# Data saved to place_Risley.json
# Place: Risley
# Data saved to place_Sandiacre.json
# Place: Sandiacre
# Data saved to place_Sawley.json
# Place: Sawley
# Data saved to place_Shipley.json
# Place: Shipley
# Data saved to place_Shuckstone.json
# Place: Shuckstone
# Data saved to place_Smalley.json
# Place: Smalley
# Data saved to place_Smithycote.json
# Place: Smithycote
# Data saved to place_Spondon.json
# Place: Spondon
# Data saved to place_Stanley.json
# Place: Stanley
# Data saved to place_Stanton [-by-Dale].json
# Place: Stanton [-by-Dale]
# Data saved to place_Vlvritune.json
# Place: Vlvritune
# Data saved to place_Clifton [Campville].json
# Place: Clifton [Campville]
# Data saved to place_Croxall.json
# Place: Croxall
# Data saved to place_Edingale.json
# Place: Edingale
# Data saved to place_Stapenhill.json
# Place: Stapenhill
# Data saved to place_Winshill.json
# Place: Winshill
# Data saved to place_Alfreton.json
# Place: Alfreton
# Data saved to place_Ashover.json
# Place: Ashover
# Data saved to place_Barlborough.json
# Place: Barlborough
# Data saved to place_Barlow.json
# Place: Barlow
# Data saved to place_Beighton.json
# Place: Beighton
# Data saved to place_Blingsby.json
# Place: Blingsby
# Data saved to place_Bolsover.json
# Place: Bolsover
# Data saved to place_Boythorpe.json
# Place: Boythorpe
# Data saved to place_Bramley [Vale].json
# Place: Bramley [Vale]
# Data saved to place_Brimington.json
# Place: Brimington
# Data saved to place_Calow.json
# Place: Calow
# Data saved to place_Chesterfield.json
# Place: Chesterfield
# Data saved to place_Clowne.json
# Place: Clowne
# Data saved to place_[Coal] Aston.json
# Place: [Coal] Aston
# Data saved to place_Dore.json
# Place: Dore
# Data saved to place_Dronfield.json
# Place: Dronfield
# Data saved to place_Duckmanton and [Long] Duckmanton.json
# Place: Duckmanton and [Long] Duckmanton
# Data saved to place_Eckington.json
# Place: Eckington
# Data saved to place_Egstow.json
# Place: Egstow
# Data saved to place_Elmton.json
# Place: Elmton
# Data saved to place_Esnotrewic.json
# Place: Esnotrewic
# Data saved to place_Glapwell.json
# Place: Glapwell
# Data saved to place_[Great] Barlow.json
# Place: [Great] Barlow
# Data saved to place_Greyhirst.json
# Place: Greyhirst
# Data saved to place_Handley.json
# Place: Handley
# Data saved to place_Hardstoft.json
# Place: Hardstoft
# Data saved to place_Holme.json
# Place: Holme
# Data saved to place_Holmesfield.json
# Place: Holmesfield
# Data saved to place_Killamarsh.json
# Place: Killamarsh
# Data saved to place_Lowne.json
# Place: Lowne
# Data saved to place_[Middle, Nether and West] Handley.json
# Place: [Middle, Nether and West] Handley
# Data saved to place_Morton.json
# Place: Morton
# Data saved to place_Mosborough.json
# Place: Mosborough
# Data saved to place_[Nether and Upper] Pilsley.json
# Place: [Nether and Upper] Pilsley
# Data saved to place_Newbold and [Upper] Newbold.json
# Place: Newbold and [Upper] Newbold
# Data saved to place_Newton.json
# Place: Newton
# Data saved to place_[North?] Wingfield.json
# Place: [North?] Wingfield
# Data saved to place_Norton and [Little] Norton.json
# Place: Norton and [Little] Norton
# Data saved to place_Ogston.json
# Place: Ogston
# Data saved to place_[Old] Brampton.json
# Place: [Old] Brampton
# Data saved to place_[Old] Tupton.json
# Place: [Old] Tupton
# Data saved to place_[Old] Whittington.json
# Place: [Old] Whittington
# Data saved to place_Owlcotes?.json
# Place: Owlcotes?
# Data saved to place_Padinc.json
# Place: Padinc
# Data saved to place_Palterton.json
# Place: Palterton
# Data saved to place_Rauenesholm.json
# Place: Rauenesholm
# Data saved to place_Rowthorne.json
# Place: Rowthorne
# Data saved to place_Scarcliffe.json
# Place: Scarcliffe
# Data saved to place_Shirland.json
# Place: Shirland
# Data saved to place_[South] Normanton.json
# Place: [South] Normanton
# Data saved to place_[South?] Wingfield.json
# Place: [South?] Wingfield
# Data saved to place_Stainsby.json
# Place: Stainsby
# Data saved to place_Staveley.json
# Place: Staveley
# Data saved to place_[Stony] Houghton.json
# Place: [Stony] Houghton
# Data saved to place_Stretton.json
# Place: Stretton
# Data saved to place_Sutton [Scarsdale].json
# Place: Sutton [Scarsdale]
# Data saved to place_Tapton.json
# Place: Tapton
# Data saved to place_[Temple] Normanton.json
# Place: [Temple] Normanton
# Data saved to place_Tibshelf.json
# Place: Tibshelf
# Data saved to place_Totley.json
# Place: Totley
# Data saved to place_Tunstall.json
# Place: Tunstall
# Data saved to place_Ufton.json
# Place: Ufton
# Data saved to place_Unstone.json
# Place: Unstone
# Data saved to place_Upton.json
# Place: Upton
# Data saved to place_Wadshelf.json
# Place: Wadshelf
# Data saved to place_Walton.json
# Place: Walton
# Data saved to place_Wessington.json
# Place: Wessington
# Data saved to place_Whitwell.json
# Place: Whitwell
# Data saved to place_Williamthorpe.json
# Place: Williamthorpe
# Data saved to place_Wingerworth.json
# Place: Wingerworth
# Data saved to place_Rocester.json
# Place: Rocester
# Data saved to place_Appleby [Magna].json
# Place: Appleby [Magna]
# Data saved to place_Bolun.json
# Place: Bolun
# Data saved to place_Bretby.json
# Place: Bretby
# Data saved to place_Caldwell.json
# Place: Caldwell
# Data saved to place_Catton.json
# Place: Catton
# Data saved to place_Coton [-in-the-Elms].json
# Place: Coton [-in-the-Elms]
# Data saved to place_Drakelowe.json
# Place: Drakelowe
# Data saved to place_Foremark.json
# Place: Foremark
# Data saved to place_Hartshorne.json
# Place: Hartshorne
# Data saved to place_Hearthcote.json
# Place: Hearthcote
# Data saved to place_Ingleby.json
# Place: Ingleby
# Data saved to place_Lullington.json
# Place: Lullington
# Data saved to place_Melbourne.json
# Place: Melbourne
# Data saved to place_Milton.json
# Place: Milton
# Data saved to place_Newton [Solney].json
# Place: Newton [Solney]
# Data saved to place_Repton.json
# Place: Repton
# Data saved to place_Rosliston.json
# Place: Rosliston
# Data saved to place_Smisby.json
# Place: Smisby
# Data saved to place_Stanton.json
# Place: Stanton
# Data saved to place_Stanton [-by-Bridge].json
# Place: Stanton [-by-Bridge]
# Data saved to place_Stretton [-en-le-Field].json
# Place: Stretton [-en-le-Field]
# Data saved to place_Swadlincote.json
# Place: Swadlincote
# Data saved to place_Ticknall.json
# Place: Ticknall
# Data saved to place_Walton [-on-Trent].json
# Place: Walton [-on-Trent]
# Data saved to derbyshire.json

# %% [markdown]
# # Exercise 3
#
# Now that we have the ids for all the places in Derbyshire, we can load all their details... And from their details, we can list all the details of their manors. Go fetch the data!
#
# P.S.: remember to save the data to avoid downloading it every time

# %%
import os

places_folder_path = "./data/Places/"
count = 0

for place_filename in os.listdir(places_folder_path):
    place_file_path = os.path.join(places_folder_path, place_filename)
    #print(f"Fetching data for place {place_file_path}")
    if not os.path.exists("./data/Manors"):
        os.makedirs("./data/Manors")
    
    with open(place_file_path, "r") as file:
        place_data = dict(json.load(file))
        folder_path = "./data/Manors/" + str(place_data['vill'] + "/")

        #print(f"Checking place folder {folder_path}")
        if not os.path.exists(folder_path):
            #print(f"Creating folder {folder_path}")
            os.makedirs(folder_path)

        #print("Fetching and saving " + str(len(place_data['manors'])) + " manors...")
        for manor_details in place_data['manors']:
            manor_id = manor_details['id']
            #print(f"url : " + str(f"https://opendomesday.org/api/1.0/manor/{manor_id}/"))
            manor_response = requests.get(f"https://opendomesday.org/api/1.0/manor/{manor_id}/")
            manor_data = manor_response.json()
            #print(manor_data)
            #print(f"Saving manor in " + f"Manors/{place_data['vill']}/manor_{manor_data['id']}.json")
            save_to_json(manor_response.json(), f"Manors/{place_data['vill']}/manor_{manor_data['id']}.json")
            count += 1
            
print(f"Saved {count} manors.")
# Out:
# Saving manor in Manors/Herdebi/manor_13069.json
# Data saved to Manors/Herdebi/manor_13069.json
# Saving manor in Manors/Herdebi/manor_13166.json
# Data saved to Manors/Herdebi/manor_13166.json
# Saving manor in Manors/Kinder/manor_12973.json
# Data saved to Manors/Kinder/manor_12973.json
# Saving manor in Manors/Aston [-on-Trent]/manor_12981.json
# Data saved to Manors/Aston [-on-Trent]/manor_12981.json
# Saving manor in Manors/Aston [-on-Trent]/manor_13096.json
# Data saved to Manors/Aston [-on-Trent]/manor_13096.json
# Saving manor in Manors/Wyaston/manor_13062.json
# Data saved to Manors/Wyaston/manor_13062.json
# Saving manor in Manors/Alkmonton/manor_13038.json
# Data saved to Manors/Alkmonton/manor_13038.json
# Saving manor in Manors/Hardstoft/manor_13002.json
# Data saved to Manors/Hardstoft/manor_13002.json
# Saving manor in Manors/Handley/manor_13205.json
# Data saved to Manors/Handley/manor_13205.json
# Saving manor in Manors/Handley/manor_13206.json
# Data saved to Manors/Handley/manor_13206.json
# Saving manor in Manors/Rowthorne/manor_13198.json
# Data saved to Manors/Rowthorne/manor_13198.json
# Saving manor in Manors/Donisthorpe/manor_10831.json
# Data saved to Manors/Donisthorpe/manor_10831.json
# Saving manor in Manors/Donisthorpe/manor_13185.json
# Data saved to Manors/Donisthorpe/manor_13185.json
# Saving manor in Manors/Pentrich/manor_13158.json
# Data saved to Manors/Pentrich/manor_13158.json
# Saving manor in Manors/Ludwell/manor_13014.json
# Data saved to Manors/Ludwell/manor_13014.json
# Saving manor in Manors/Edlaston/manor_13062.json
# Data saved to Manors/Edlaston/manor_13062.json
# Saving manor in Manors/[Old] Tupton/manor_12951.json
# Data saved to Manors/[Old] Tupton/manor_12951.json
# Saving manor in Manors/[Old] Tupton/manor_13122.json
# Data saved to Manors/[Old] Tupton/manor_13122.json
# Saving manor in Manors/[Old] Tupton/manor_13202.json
# Data saved to Manors/[Old] Tupton/manor_13202.json
# Saving manor in Manors/[Higher and Lower] Dinting/manor_12973.json
# Data saved to Manors/[Higher and Lower] Dinting/manor_12973.json
# Saving manor in Manors/Willington/manor_13153.json
# Data saved to Manors/Willington/manor_13153.json
# Saving manor in Manors/[Old] Brampton/manor_13121.json
# Data saved to Manors/[Old] Brampton/manor_13121.json
# Saving manor in Manors/[Old] Brampton/manor_13170.json
# Data saved to Manors/[Old] Brampton/manor_13170.json
# Saving manor in Manors/[Old] Brampton/manor_13171.json
# Data saved to Manors/[Old] Brampton/manor_13171.json
# Saving manor in Manors/[Middle, Nether and West] Handley/manor_13140.json
# Data saved to Manors/[Middle, Nether and West] Handley/manor_13140.json
# Saving manor in Manors/Mapleton/manor_12957.json
# Data saved to Manors/Mapleton/manor_12957.json
# Saving manor in Manors/Welledene/manor_12956.json
# Data saved to Manors/Welledene/manor_12956.json
# Saving manor in Manors/Mercaston/manor_13099.json
# Data saved to Manors/Mercaston/manor_13099.json
# Saving manor in Manors/Ravenstone/manor_10954.json
# Data saved to Manors/Ravenstone/manor_10954.json
# Saving manor in Manors/Ravenstone/manor_13184.json
# Data saved to Manors/Ravenstone/manor_13184.json
# Saving manor in Manors/Snitterton/manor_12955.json
# Data saved to Manors/Snitterton/manor_12955.json
# Saving manor in Manors/Ible/manor_12955.json
# Data saved to Manors/Ible/manor_12955.json
# Saving manor in Manors/Scarcliffe/manor_13138.json
# Data saved to Manors/Scarcliffe/manor_13138.json
# Saving manor in Manors/Ireton/manor_13095.json
# Data saved to Manors/Ireton/manor_13095.json
# Saving manor in Manors/Hallam/manor_13165.json
# Data saved to Manors/Hallam/manor_13165.json
# Saving manor in Manors/Yeaveley/manor_13064.json
# Data saved to Manors/Yeaveley/manor_13064.json
# Saving manor in Manors/Greyhirst/manor_12946.json
# Data saved to Manors/Greyhirst/manor_12946.json
# Saving manor in Manors/Sutton [Scarsdale]/manor_12998.json
# Data saved to Manors/Sutton [Scarsdale]/manor_12998.json
# Saving manor in Manors/Newbold and [Upper] Newbold/manor_12944.json
# Data saved to Manors/Newbold and [Upper] Newbold/manor_12944.json
# Saving manor in Manors/[Nether and Upper] Pilsley/manor_13122.json
# Data saved to Manors/[Nether and Upper] Pilsley/manor_13122.json
# Saving manor in Manors/Cromford/manor_12956.json
# Data saved to Manors/Cromford/manor_12956.json
# Saving manor in Manors/Shuckstone/manor_13144.json
# Data saved to Manors/Shuckstone/manor_13144.json
# Saving manor in Manors/Barlow/manor_13200.json
# Data saved to Manors/Barlow/manor_13200.json
# Saving manor in Manors/Matlock/manor_12955.json
# Data saved to Manors/Matlock/manor_12955.json
# Data saved to Manors/Hathersage/manor_13150.json
# Saving manor in Manors/Ivonbrook [Grange]/manor_13004.json
# Data saved to Manors/Ivonbrook [Grange]/manor_13004.json
# Saving manor in Manors/Youlgrave/manor_13079.json
# Data saved to Manors/Youlgrave/manor_13079.json
# Saving manor in Manors/Ballidon/manor_13155.json
# Data saved to Manors/Ballidon/manor_13155.json
# Saving manor in Manors/Cottons/manor_12962.json
# Data saved to Manors/Cottons/manor_12962.json
# Saving manor in Manors/Cottons/manor_13092.json
# Data saved to Manors/Cottons/manor_13092.json
# Saving manor in Manors/Breaston/manor_13068.json
# Data saved to Manors/Breaston/manor_13068.json
# Saving manor in Manors/Breaston/manor_13131.json
# Data saved to Manors/Breaston/manor_13131.json
# Saving manor in Manors/Breaston/manor_13174.json
# Data saved to Manors/Breaston/manor_13174.json
# Saving manor in Manors/Breaston/manor_13191.json
# Data saved to Manors/Breaston/manor_13191.json
# Saving manor in Manors/Draycott/manor_12983.json
# Data saved to Manors/Draycott/manor_12983.json
# Saving manor in Manors/Calow/manor_13208.json
# Data saved to Manors/Calow/manor_13208.json
# Saving manor in Manors/Blingsby/manor_13002.json
# Data saved to Manors/Blingsby/manor_13002.json
# Saving manor in Manors/Calver/manor_12971.json
# Data saved to Manors/Calver/manor_12971.json
# Saving manor in Manors/Fenton/manor_13059.json
# Data saved to Manors/Fenton/manor_13059.json
# Saving manor in Manors/Boulton/manor_13152.json
# Data saved to Manors/Boulton/manor_13152.json
# Saving manor in Manors/Bamford/manor_13150.json
# Data saved to Manors/Bamford/manor_13150.json
# Saving manor in Manors/Stoke/manor_12972.json
# Data saved to Manors/Stoke/manor_12972.json
# Saving manor in Manors/Priestcliffe/manor_12971.json
# Data saved to Manors/Priestcliffe/manor_12971.json
# Saving manor in Manors/Monyash/manor_12970.json
# Data saved to Manors/Monyash/manor_12970.json
# Saving manor in Manors/Birchills/manor_12971.json
# Data saved to Manors/Birchills/manor_12971.json
# Saving manor in Manors/Cowley/manor_13006.json
# Data saved to Manors/Cowley/manor_13006.json
# Saving manor in Manors/[Cold] Eaton/manor_12958.json
# Data saved to Manors/[Cold] Eaton/manor_12958.json
# Saving manor in Manors/One Ash/manor_12970.json
# Data saved to Manors/One Ash/manor_12970.json
# Saving manor in Manors/Risley/manor_13192.json
# Data saved to Manors/Risley/manor_13192.json
# Saving manor in Manors/Risley/manor_13219.json
# Data saved to Manors/Risley/manor_13219.json
# Saving manor in Manors/Weston [Underwood]/manor_13162.json
# Data saved to Manors/Weston [Underwood]/manor_13162.json
# Saving manor in Manors/Longdendale/manor_12973.json
# Data saved to Manors/Longdendale/manor_12973.json
# Saving manor in Manors/Wensley/manor_12955.json
# Data saved to Manors/Wensley/manor_12955.json
# Saving manor in Manors/Linton/manor_10837.json
# Data saved to Manors/Linton/manor_10837.json
# Saving manor in Manors/Linton/manor_13022.json
# Data saved to Manors/Linton/manor_13022.json
# Saving manor in Manors/Chunal/manor_12973.json
# Data saved to Manors/Chunal/manor_12973.json
# Saving manor in Manors/Marsh?/manor_13220.json
# Data saved to Manors/Marsh?/manor_13220.json
# Data saved to Manors/[Nether and Over] Haddon/manor_12970.json
# Saving manor in Manors/Thurvaston/manor_13063.json
# Data saved to Manors/Thurvaston/manor_13063.json
# Saving manor in Manors/Thurvaston/manor_13067.json
# Data saved to Manors/Thurvaston/manor_13067.json
# Saving manor in Manors/Ambaston/manor_13127.json
# Data saved to Manors/Ambaston/manor_13127.json
# Saving manor in Manors/Mosborough/manor_13135.json
# Data saved to Manors/Mosborough/manor_13135.json
# Saving manor in Manors/Smithycote/manor_13111.json
# Data saved to Manors/Smithycote/manor_13111.json
# Saving manor in Manors/[Great and Little] Hucklow/manor_13115.json
# Data saved to Manors/[Great and Little] Hucklow/manor_13115.json
# Saving manor in Manors/Radbourne/manor_13102.json
# Data saved to Manors/Radbourne/manor_13102.json
# Saving manor in Manors/Makeney/manor_13069.json
# Data saved to Manors/Makeney/manor_13069.json
# Saving manor in Manors/Owlcotes?/manor_13122.json
# Data saved to Manors/Owlcotes?/manor_13122.json
# Saving manor in Manors/Wormhill/manor_13082.json
# Data saved to Manors/Wormhill/manor_13082.json
# Saving manor in Manors/Chaddesden/manor_13071.json
# Data saved to Manors/Chaddesden/manor_13071.json
# Saving manor in Manors/Offcote/manor_12957.json
# Data saved to Manors/Offcote/manor_12957.json
# Saving manor in Manors/Stanton [-by-Dale]/manor_13174.json
# Data saved to Manors/Stanton [-by-Dale]/manor_13174.json
# Saving manor in Manors/[Old] Whittington/manor_12944.json
# Data saved to Manors/[Old] Whittington/manor_12944.json
# Saving manor in Manors/Sedsall/manor_13053.json
# Data saved to Manors/Sedsall/manor_13053.json
# Saving manor in Manors/Catton/manor_13020.json
# Data saved to Manors/Catton/manor_13020.json
# Saving manor in Manors/[Long] Eaton/manor_12984.json
# Data saved to Manors/[Long] Eaton/manor_12984.json
# Saving manor in Manors/Tideswell/manor_12972.json
# Data saved to Manors/Tideswell/manor_12972.json
# Saving manor in Manors/Derby/manor_13223.json
# Data saved to Manors/Derby/manor_13223.json
# Saving manor in Manors/Derby/manor_13224.json
# Data saved to Manors/Derby/manor_13224.json
# Saving manor in Manors/Derby/manor_13226.json
# Data saved to Manors/Derby/manor_13226.json
# Saving manor in Manors/Derby/manor_13227.json
# Data saved to Manors/Derby/manor_13227.json
# Saving manor in Manors/Derby/manor_13228.json
# Data saved to Manors/Derby/manor_13228.json
# Saving manor in Manors/Derby/manor_13229.json
# Data saved to Manors/Derby/manor_13229.json
# Saving manor in Manors/Derby/manor_13230.json
# Data saved to Manors/Derby/manor_13230.json
# Saving manor in Manors/Derby/manor_13231.json
# Data saved to Manors/Derby/manor_13231.json
# Saving manor in Manors/Derby/manor_13233.json
# Data saved to Manors/Derby/manor_13233.json
# Saving manor in Manors/Derby/manor_13234.json
# Data saved to Manors/Derby/manor_13234.json
# Saving manor in Manors/Rosliston/manor_12959.json
# Data saved to Manors/Rosliston/manor_12959.json
# Saving manor in Manors/[Coal] Aston/manor_13204.json
# Data saved to Manors/[Coal] Aston/manor_13204.json
# Saving manor in Manors/Appleby [Magna]/manor_12988.json
# Data saved to Manors/Appleby [Magna]/manor_12988.json
# Saving manor in Manors/Ashe/manor_13040.json
# Data saved to Manors/Ashe/manor_13040.json
# Saving manor in Manors/Cellesdene/manor_13217.json
# Data saved to Manors/Cellesdene/manor_13217.json
# Saving manor in Manors/Whitfield/manor_12973.json
# Data saved to Manors/Whitfield/manor_12973.json
# Saving manor in Manors/Holmesfield/manor_13123.json
# Data saved to Manors/Holmesfield/manor_13123.json
# Saving manor in Manors/Drakelowe/manor_13177.json
# Data saved to Manors/Drakelowe/manor_13177.json
# Saving manor in Manors/Yeldersley/manor_13048.json
# Data saved to Manors/Yeldersley/manor_13048.json
# Saving manor in Manors/Pilsley/manor_13074.json
# Data saved to Manors/Pilsley/manor_13074.json
# Saving manor in Manors/Swadlincote/manor_13179.json
# Data saved to Manors/Swadlincote/manor_13179.json
# Saving manor in Manors/Wingerworth/manor_12945.json
# Data saved to Manors/Wingerworth/manor_12945.json
# Saving manor in Manors/Breadsall/manor_13072.json
# Data saved to Manors/Breadsall/manor_13072.json
# Saving manor in Manors/Ockbrook/manor_13132.json
# Data saved to Manors/Ockbrook/manor_13132.json
# Saving manor in Manors/Brailsford/manor_13043.json
# Data saved to Manors/Brailsford/manor_13043.json
# Saving manor in Manors/Croxall/manor_13017.json
# Data saved to Manors/Croxall/manor_13017.json
# Saving manor in Manors/Hassop/manor_12971.json
# Data saved to Manors/Hassop/manor_12971.json
# Saving manor in Manors/Wessington/manor_13120.json
# Data saved to Manors/Wessington/manor_13120.json
# Saving manor in Manors/Wessington/manor_13146.json
# Data saved to Manors/Wessington/manor_13146.json
# Saving manor in Manors/[Kirk] Ireton/manor_12956.json
# Data saved to Manors/[Kirk] Ireton/manor_12956.json
# Saving manor in Manors/Ashford [-in-the-Water]/manor_12971.json
# Data saved to Manors/Ashford [-in-the-Water]/manor_12971.json
# Saving manor in Manors/Tunstall/manor_13001.json
# Data saved to Manors/Tunstall/manor_13001.json
# Saving manor in Manors/Tunstall/manor_13138.json
# Data saved to Manors/Tunstall/manor_13138.json
# Saving manor in Manors/Coton [-in-the-Elms]/manor_12990.json
# Data saved to Manors/Coton [-in-the-Elms]/manor_12990.json
# Saving manor in Manors/Smisby/manor_13183.json
# Data saved to Manors/Smisby/manor_13183.json
# Saved 442 manors.

# %% [markdown]
# # Exercise 4
#
# Now that we have a quantity of raw data, we will extract the interesting parts.
# In our case, we want to count the money paid by each manor and compare it to the number of ploughs it has.
#
#  - Can you find the corresponding json fields?
#  - Then, you can list these numbers for each manor in Derbyshire.
#  - And format this in an appropriate comma-separated values (CSV) file.
#
# Note : plough == charrue
#
# From exploration of files, I found a key in the manor dictionaries that stores the total number of ploughs name `totalploughs`. Money paid is stored in `value86` for year 86 and `value66` for year 66. The total money paid is the sum of the two.

# %%
import pandas as pd

result = pd.DataFrame(columns=['Manor id', 'Money Paid 86', 'Money Paid 66', 'Total Money Paid', 'Total Ploughs'])
manors_folder_path = "./data/Manors/"
i = 0

for place_folder_name in os.listdir(manors_folder_path):
    i += 1
    if place_folder_name == "manors.csv":
        continue
    manor_file_list = os.listdir(os.path.join(manors_folder_path, place_folder_name))
    for manor_filename in manor_file_list:
        manor_file_path = os.path.join(manors_folder_path, place_folder_name, manor_filename)
        with open(manor_file_path, "r") as file:
            manor_data = dict(json.load(file))
            # print(f"Manor id : " + str(manor_data['id']))
            # print(f"Manor value 86 : " + str(manor_data['value86']))
            # print(f"Manor value 66 : " + str(manor_data['value66']))
            # print(f"Manor totalploughs : " + str(manor_data['totalploughs']))
            result.loc[len(result.index)] = [manor_data['id'], str(float(manor_data['value86'] if manor_data['value86'] is not None else 0.0)), str(float(manor_data['value66'] if manor_data['value66'] is not None else 0.0)), str(float(manor_data['value86'] if manor_data['value86'] is not None else 0.0) + float(manor_data['value66'] if manor_data['value66'] is not None else 0.0)), manor_data['totalploughs']]
result.to_csv("./data/Manors/manors.csv", index=False, sep=",")
result.head(20)
# Out:
#     Manor id Money Paid 86 Money Paid 66 Total Money Paid  Total Ploughs
# 0      12973           0.0           2.0              2.0            0.0
# 1      13130           3.0           8.0             11.0            2.0
# 2      12975           0.8           1.0              1.8            2.0
# 3      12971           0.0           0.0              0.0            9.0
# 4      12957          1.06           0.0             1.06            8.0
# 5      12995           3.0           4.0              7.0            7.0
# 6      12984           8.0           8.0             16.0           13.0
# 7      12956           0.0           0.0              0.0           18.5
# 8      13142           1.5           4.0              5.5            4.0
# 9      12978           0.0           0.8              0.8            0.0
# 10     13015           0.5           3.0              3.5            2.0
# 11     13210           4.0           4.0              8.0            4.0
# 12     12976           1.0           1.0              2.0            5.0
# 13     13198           0.8           1.0              1.8            2.0
# 14     13001           1.5           2.0              3.5            6.0
# 15     12963           8.0          15.0             23.0           15.0
# 16     12987          10.0          25.0             35.0           13.5
# 17     13049           3.0           6.0              9.0            6.0
# 18     13006           0.5           0.5              1.0            1.0
# 19     13029           2.0           0.0              2.0            3.0

# %% [markdown]
# # Exercise 5
#
# What is the richest manor in Derbyshire?

# %%
manors_data = pd.read_csv("./data/Manors/manors.csv", sep=",")
max_value = 0
max_index = ''
for index, row in manors_data.iterrows():
    if float(row['Total Money Paid']) > max_value:
        max_value = float(row['Total Money Paid'])
        max_index = index
richest_manor_id = manors_data[manors_data.index == max_index]['Manor id'].values[0]
print(f"The richest manor in Derbyshire is manor with id " + str(richest_manor_id) + " with a total money paid of " + str(max_value) + ".")
# Out:
# The richest manor in Derbyshire is manor with id 12958 with a total money paid of 72.0.

# %% [markdown]
# # Exercise 6
#
# Give the total value paid by Derbyshire.

# %%
manors_data = pd.read_csv("./data/Manors/manors.csv", sep=",")
total_value = 0

for index, row in manors_data.iterrows():
    total_value += float(row['Total Money Paid'])

print(f"The total value paid by Derbyshire is " + str(total_value) + ".")
# Out:
# The total value paid by Derbyshire is 2718.1182999999996.

# %% [markdown]
# # Exercise 7
#
# Create a Python class. It must include all the previous functionalities. Refactor your code to make it readable, efficient, and maintainable.

# %%
class OpenDomesdayAPI:
    def __init__(self):
        self.counties = None
        self.places = None
        self.manors = None
        self.manors_data = None
        self.places_folder_path = "./data/Places/"
        self.manors_folder_path = "./data/Manors/"
    
    def save_to_json(self, data: dict, filename: str) -> None:
        with open("./data/" + filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data saved to {filename}")

    def load_from_json(self, filename: str) -> dict:
        with open("./data/" + filename, "r") as file:
            data = dict(json.load(file))
        return data

    def get_counties(self):
        response = requests.get("https://opendomesday.org/api/1.0/county")
        if response.status_code == 200:
            self.counties = response.json()
            self.save_to_json(self.counties, "counties.json")
        return self.counties

    def get_places(self, county_name: str):
        response = requests.get("https://opendomesday.org/api/1.0/county")
        if response.status_code == 200:
            data = response.json()
            for county in data:
                if county['name'] == county_name:
                    county_id = county['id']
            response = requests.get("https://opendomesday.org/api/1.0/county/" + str(county_id))
            if response.status_code == 200:
                self.places = response.json()
                self.save_to_json(self.places, f"{county_name}.json")
        return self.places

# %% [markdown]
# # Exercise 8 (optional)
#
# Add to your class a system for error handling. It must manage the following errors:
# - Connection error
# - Parsing error
# - Request error
# - Response error
# - Parameter error

# %%
class OpenDomesdayAPI:
    def __init__(self):
        self.counties = None
        self.places = dict()
        self.manors = dict()
        self.manors_data = None
        self.places_folder_path = "./data/Places/"
        self.manors_folder_path = "./data/Manors/"
    
    def save_to_json(self, data: dict, filename: str) -> None:
        with open("./data/" + filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data saved to {filename}")

    def load_from_json(self, filename: str) -> dict:
        with open("./data/" + filename, "r") as file:
            data = dict(json.load(file))
        return data

    def get_counties(self):
        try:
            response = requests.get("https://opendomesday.org/api/1.0/county")
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Request error: {e}")
            return None
        
        if response.status_code == 200:
            self.counties = response.json()
            self.save_to_json(self.counties, "counties.json")
        return self.counties

    def get_places(self, county_name: str):
        try:
            response = requests.get("https://opendomesday.org/api/1.0/county")
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Request error: {e}")
            return None
        
        if response.status_code == 200:
            data = response.json()
            for county in data:
                if county['name'] == county_name:
                    county_id = county['id']
            response = requests.get("https://opendomesday.org/api/1.0/county/" + str(county_id))
            response.raise_for_status()
            if response.status_code == 200:
                self.places = response.json()
                self.save_to_json(self.places, f"{county_name}.json")
        return self.places
    
    def get_manors(self, county_name: str) -> dict:
        try:
            response = requests.get("https://opendomesday.org/api/1.0/county")
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Request error: {e}")
            return None
        
        if response.status_code == 200:
            data = response.json()
            for county in data:
                if county['name'] == county_name:
                    county_id = county['id']
            response = requests.get("https://opendomesday.org/api/1.0/county/" + str(county_id))
            response.raise_for_status()
            if response.status_code == 200:
                self.manors = response.json()
                self.save_to_json(self.manors, f"{county_name}.json")
        return self.manors
    
    def get_richest_manor_id(self, county_name: str):
        manors_data = self.get_manors(county_name)
        if manors_data is None:
            return None
        for index, row in manors_data.iterrows():
            if float(row['Total Money Paid']) > max_value:
                max_value = float(row['Total Money Paid'])
                max_index = index
        richest_manor_id = manors_data[manors_data.index == max_index]['Manor id'].values[0]
        return richest_manor_id
    
    def get_total_value_paid(self, county_name: str):
        places = list(self.get_places(county_name))
        total_value = 0
        for place in places:
            manors = list(self.get_manors(place['name']))
            for manor in manors:
                total_value += float(float(manor['value86'] if manor['value86'] is not None else 0.0) + float(manor['value66'] if manor['value66'] is not None else 0.0))
